# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
plt.style.use('ggplot')

# %%
df = pd.read_csv('Financial Sample.csv')
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.head(20)
# Out:
#              Segment                   Country     Product   Discount Band   \
# 0         Government                    Canada   Carretera            None
# 1         Government                   Germany   Carretera            None
# 2          Midmarket                    France   Carretera            None
# 3          Midmarket                   Germany   Carretera            None
# 4          Midmarket                    Mexico   Carretera            None
# 5         Government                   Germany   Carretera            None
# 6          Midmarket                   Germany     Montana            None
# 7   Channel Partners                    Canada     Montana            None
# 8         Government                    France     Montana            None
# 9   Channel Partners                   Germany     Montana            None
# 10         Midmarket                    Mexico     Montana            None
# ...

# %%
df.dtypes
# Out:
# Segment                   object
# Country                   object
#  Product                  object
#  Discount Band            object
# Units Sold               float64
#  Manufacturing Price      object
#  Sale Price               object
#  Gross Sales              object
#  Discounts                object
#   Sales                   object
#  COGS                     object
#  Profit                   object
# Date                      object
# Month Number               int64
#  Month Name               object
# Year                       int64
# dtype: object

# %%
df.isnull().count()
# Out:
# Segment                  700
# Country                  700
#  Product                 700
#  Discount Band           700
# Units Sold               700
#  Manufacturing Price     700
#  Sale Price              700
#  Gross Sales             700
#  Discounts               700
#   Sales                  700
#  COGS                    700
#  Profit                  700
# Date                     700
# Month Number             700
#  Month Name              700
# Year                     700
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
# Units Sold               0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
df.isna().head()
# Out:
#    Segment  Country   Product    Discount Band   Units Sold  \
# 0    False    False      False            False       False
# 1    False    False      False            False       False
# 2    False    False      False            False       False
# 3    False    False      False            False       False
# 4    False    False      False            False       False
#
#     Manufacturing Price    Sale Price    Gross Sales    Discounts     Sales   \
# 0                  False         False          False        False     False
# 1                  False         False          False        False     False
# 2                  False         False          False        False     False
# 3                  False         False          False        False     False
# 4                  False         False          False        False     False
#
#     COGS    Profit    Date  Month Number   Month Name    Year
# 0   False     False  False         False         False  False
# ...

# %%
df.Country.unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
#df.product.unique()

# %%
df.query('Country == "Canada"').sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of               Segment Country     Product   Discount Band   Units Sold  \
# 0          Government  Canada   Carretera            None       1618.5
# 7    Channel Partners  Canada     Montana            None       2518.0
# 11         Enterprise  Canada     Montana            None       2665.5
# 14         Enterprise  Canada     Montana            None        345.0
# 16         Government  Canada       Paseo            None        292.0
# ..                ...     ...          ...             ...         ...
# 671         Midmarket  Canada       Paseo            High       1614.0
# 674         Midmarket  Canada       Paseo            High       2559.0
# 688        Government  Canada         VTT            High        865.5
# 692        Enterprise  Canada         VTT            High       2954.0
# 698        Government  Canada       Paseo            High        723.0
#
# ...

# %%
df2=df1.copy()
df2.drop('Society',axis=1,inplace=True)

# %%
ax = df['Year'].value_counts().plot(kind='bar', title = 'Year of Sales')
ax.set_xlabel('Year')
ax.set_ylabel('Number')
# Out:
# Text(0, 0.5, 'Number')

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
sns.relplot(x=' Manufacturing Price ',y='Country',hue=' Product ',data=df)
# Out:
# C:\Users\sreej\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x = 'Country', y = ' Product ',hue = 'Year', color='y', data = df)
# Out:
# <Axes: xlabel='Country', ylabel=' Product '>

# %%
plt.figure(figsize=(8, 6))
plt.bar(' Product ', '  Sales ',data=df,fill='True',hatch='|-*-|',color='r')
plt.xlabel('Product')
plt.ylabel('Sales')
plt.title('Sales by Product')
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df2,hue='Month Number',diag_kind='hist')
plt.title('Pair Plot')
plt.show()
# Out:
# C:\Users\sreej\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x = '  Sales ', y = ' Month Name ',hue = ' Month Name ', data = df)
# Out:
# <Axes: xlabel='  Sales ', ylabel=' Month Name '>

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
x=(df[' Month Name '])
y=(df['  Sales '])
plt.bar(x,y)
plt.xlabel(' Month Name ')
plt.ylabel('Sales')
plt.title(' Month wise Sales')
plt.show()

# %%
x=(df['Country'])
y=(df['Units Sold'])
plt.bar(x,y)
plt.xlabel(' COUNTRY ')
plt.ylabel('UNITS SOLD')
plt.title('Units sold by country')
plt.show()

# %%
sns.lineplot(x=' Product ',y='  Sales ',data=df,hue='Year')
plt.title("sales by product")
plt.show()

# %%
sns.violinplot(x='Country',y = 'Units Sold', data = df )
plt.title('Units sold per country', color='r')
# Out:
# Text(0.5, 1.0, 'Units sold per country')

# %%
x=(df['Country'])
y=(df['Units Sold'])
plt.hist(y)
plt.title('Histogram plot',color='g',size=20,)
plt.show()
